# %% [markdown]
# # TRG-PINN release demo
#
# This notebook inspects canonical comparison outputs without training.

# %%
from pathlib import Path
import pandas as pd

repo = Path.cwd().resolve()
if not (repo / 'results').is_dir():
    repo = repo.parent
table = pd.read_csv(
    repo / 'results' / 'benchmark_comparison' /
    'benchmark_comparison_formatted.csv',
    index_col=0,
)
table

# %%
reductions = pd.read_csv(
    repo / 'results' / 'benchmark_comparison' /
    'pinn_trg_reductions.csv'
)
reductions

# %% [markdown]
# Run `python scripts/verify_release.py` from the repository root.
